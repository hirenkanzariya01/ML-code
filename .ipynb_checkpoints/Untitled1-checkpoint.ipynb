# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import plotly.express as px
from sklearn.preprocessing import LabelEncoder

# %%
df= px.data.tips()

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
lebelencoder = LabelEncoder()

# %%
df['sex'] = lebelencoder.fit_transform(df['sex'])

# %%
df.head()
# Out:
#    total_bill   tip  sex smoker  day    time  size
# 0       16.99  1.01    0     No  Sun  Dinner     2
# 1       10.34  1.66    1     No  Sun  Dinner     3
# 2       21.01  3.50    1     No  Sun  Dinner     3
# 3       23.68  3.31    1     No  Sun  Dinner     2
# 4       24.59  3.61    0     No  Sun  Dinner     4

# %%
df['smoker'] = lebelencoder.fit_transform(df['smoker'])

# %%
df.sample(5)
# Out:
#      total_bill  tip  sex  smoker  day    time  size
# 234       15.53  3.0    1       1  Sat  Dinner     2
# 154       19.77  2.0    1       0  Sun  Dinner     4
# 184       40.55  3.0    1       1  Sun  Dinner     2
# 215       12.90  1.1    0       1  Sat  Dinner     2
# 217       11.59  1.5    1       1  Sat  Dinner     2

# %%
df['day'] = lebelencoder.fit_transform(df['day'])

# %%
df.sample(5)
# Out:
#      total_bill   tip  sex  smoker  day    time  size
# 139       13.16  2.75    0       0    3   Lunch     2
# 113       23.95  2.55    1       0    2  Dinner     2
# 59        48.27  6.73    1       0    1  Dinner     4
# 37        16.93  3.07    0       0    1  Dinner     3
# 140       17.47  3.50    0       0    3   Lunch     2

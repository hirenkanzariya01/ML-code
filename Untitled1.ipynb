# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import plotly.express as px
from sklearn.preprocessing import LabelEncoder

# %%
df= px.data.tips()

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
lebelencoder = LabelEncoder()

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
col = ['sex', 'smoker', 'day', 'time', 'day']

# %%
for c in col:
    df[c] = lebelencoder.fit_transform(df[c])

# %%
df.head()
# Out:
#    total_bill   tip  sex  smoker  day  time  size
# 0       16.99  1.01    0       0    2     0     2
# 1       10.34  1.66    1       0    2     0     3
# 2       21.01  3.50    1       0    2     0     3
# 3       23.68  3.31    1       0    2     0     2
# 4       24.59  3.61    0       0    2     0     4

# %%
df= px.data.tips()

# %%
df = pd.get_dummies(df, columns=['day'], dtype=int)

# %%
df.sample(5)
# Out:
#      total_bill   tip     sex smoker    time  size  day_Fri  day_Sat  day_Sun  \
# 94        22.75  3.25  Female     No  Dinner     2        1        0        0
# 36        16.31  2.00    Male     No  Dinner     3        0        1        0
# 116       29.93  5.07    Male     No  Dinner     4        0        0        1
# 121       13.42  1.68  Female     No   Lunch     2        0        0        0
# 25        17.81  2.34    Male     No  Dinner     4        0        1        0
#
#      day_Thur
# 94          0
# 36          0
# 116         0
# 121         1
# 25          0

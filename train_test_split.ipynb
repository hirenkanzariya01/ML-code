# %%
import numpy as np 
import pandas as pd 
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('datasets/top_rated_tv.csv')

# %%
df.shape
# Out:
# (2408, 7)

# %%
df.head()
# Out:
#   first_air_date                           name  \
# 0     2008-01-20                   Breaking Bad
# 1     2023-09-29  Frieren: Beyond Journey's End
# 2     2015-11-06                     Reply 1988
# 3     2005-02-21     Avatar: The Last Airbender
# 4     2021-11-06                         Arcane
#
#                                             overview  popularity  \
# 0  Walter White, a New Mexico chemistry teacher, ...    122.1631
# 1  Decades after her party defeated the Demon Kin...     86.7104
# 2  Take a nostalgic trip back to the late 1980s t...     15.7551
# 3  In a war-torn world of elemental magic, a youn...     40.7230
# 4  Amid the stark discord of twin cities Piltover...     36.7751
#
#    vote_average  vote_count  adult
# 0         8.942       17539  False
# 1         8.805         782  False
# 2         8.800         204  False
# 3         8.756        4771  False
# 4         8.755        5821  False

# %%
df.columns
# Out:
# Index(['first_air_date', 'name', 'overview', 'popularity', 'vote_average',
#        'vote_count', 'adult'],
#       dtype='object')

# %%
X = df[['first_air_date', 'name', 'overview', 'popularity', 'vote_average',
        'adult']]
y = df['vote_count']
